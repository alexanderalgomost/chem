# %%
# %pylab inline
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.feature_extraction import DictVectorizer as DV
import sklearn.cluster as cluster
import numpy as np
from sklearn import metrics
import sklearn.cluster as cluster
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
from pandas.tools.plotting import scatter_matrix
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pd.set_option('display.max_columns', None)
import matplotlib as mpl
mpl.rcParams['font.family'] = 'fantasy'
mpl.rcParams['font.fantasy'] = 'Arial'

# %%
data = pd.read_excel('megadata_dev.xlsx')
data = data.convert_objects(convert_numeric=True)

# %%
df.columns
# Out:
# Index([u'Филиал', u'Область', u'Город', u'Магазин', u'Код 1С', u'Дата открытия салона', u'Дата закрытия салона', u' Количество отработанных месяцев в 2014  ', u' Количество отработанных дней в 2014  ', u' Численность населения, тыс. чел. ', u'Расположение ССМ, ТЦ/Street', u'Площадь общая, кв.м.', u'Среднее кол-во персонала в салоне, чел.', u' Подключения, аб. ', u' Подключения B2C, аб. ', u' Опции, шт. ', u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ', u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ', u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ', u' Аксессуары, шт. ', u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ', u' Консультации по CRM, шт. ', u' Действия по CRM, шт. ', u' Сервисные операции, оплачиваемые оператором, шт. ', u' Среднее количество принятых платежей через кассу в мес., шт. ', u' Выручка за оказание услуг, ру
# ...

# %% [markdown]
# ## Флагманы

# %%
def printByClusters(texts, labels):
    n_clust = len(np.unique(labels))
    for num in range(n_clust):
        print ('---------- %d----------'%num)
        res = np.where( labels == num )
        for r in res[0]:
            print (texts[r])

# %%
df = data[data[ u'Тип салона']== u'Флагман']
col = [u'Филиал', u'Область', u'Город', u'Магазин', u'Код 1С', u'Дата открытия салона', u'Дата закрытия салона',\
       u' Количество отработанных месяцев в 2014  ', u' Количество отработанных дней в 2014  ', u' Численность населения, тыс. чел. ',\
       u'Расположение ССМ, ТЦ/Street', u'Площадь общая, кв.м.', u'Среднее кол-во персонала в салоне, чел.',\
       u' Подключения, аб. ', u' Подключения B2C, аб. ', u' Опции, шт. ', u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ',\
       u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ', \
       u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ', u' Аксессуары, шт. ', \
       u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ', \
       u' Консультации по CRM, шт. ', u' Действия по CRM, шт. ', u' Сервисные операции, оплачиваемые оператором, шт. ', \
       u' Средний трафик в мес., чел. ', u' Среднее количество принятых платежей через кассу в мес., шт. ',\
       u' Среднее количество платежей через собственные терминалы в мес., шт. ',\
       u' Средний очищенный трафик  от платежей (кассы, терминалы) в мес., чел. ', \
       u' Выручка за оказание услуг, руб. ', u' Товарная выручка, руб. ', u' Валовая прибыль, руб. ', u' Общая себестоимость товара, руб. ',\
       u' ФОТ салона, руб. ', u' Стоимость аренды и эксплуатация, руб. ', u' OPEX + S&M, руб. ', u' Товарная выручка ССМ в мес, руб. ',\
       u' Общая выручка ССМ в мес, руб. ', u' Прибыль ССМ в мес., руб ', u' OPEX + S&M ССМ в мес., руб. ',\
       u'Коэф-т  затрат к 1 руб. выручки', u'Коэф-т затрат к 1 руб. прибыли', u'Средняя выручка на 1 кв.м. в мес., руб.', \
       u'Средняя прибыль на 1 кв.м. в мес., руб.']
df = df[col]

# %%
col = [u' Подключения, аб. ',u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ',\
       u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ',  u' Аксессуары, шт. ', \
       u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ', \
       u' Средний трафик в мес., чел. ', u' Среднее количество принятых платежей через кассу в мес., шт. ',\
       u' Выручка за оказание услуг, руб. ', u' Товарная выручка, руб. ', u' Валовая прибыль, руб. ', u' Общая себестоимость товара, руб. ',\
       u' ФОТ салона, руб. ', u' Стоимость аренды и эксплуатация, руб. ', u' OPEX + S&M, руб. ',\
       u'Коэф-т затрат к 1 руб. прибыли', u'Средняя прибыль на 1 кв.м. в мес., руб.']
df_sc = df[col]
#plt.xlabel(u' Численность населения, тыс. чел. ')
#plt.ylabel(u' Все мобильное оборудование ')
fig, axes = plt.subplots(nrows=4, ncols=3,figsize = (20,20))
axes[0,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ']])
axes[0,0].set_xlabel(u' Численность населения')
axes[0,0].set_ylabel(u' Все мобильное оборудование')

axes[1,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Товарная выручка, руб. ']])
axes[1,0].set_xlabel(u' Численность населения')
axes[1,0].set_ylabel(u' Товарная выручка, руб. ')

axes[2,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[2,0].set_xlabel(u' Численность населения')
axes[2,0].set_ylabel(u' Стоимость аренды и эксплуатация, руб. ')

axes[3,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[u' OPEX + S&M, руб. ']])
axes[3,0].set_xlabel(u' Численность населения')
axes[3,0].set_ylabel(u' OPEX + S&M, руб. ')


axes[0,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' OPEX + S&M, руб. ']])
axes[0,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[0,1].set_ylabel(u' OPEX + S&M, руб. ')

axes[1,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[1,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[1,1].set_ylabel( u' Стоимость аренды и эксплуатация, руб. ')

axes[2,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u'Площадь общая, кв.м.']])
axes[2,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[2,1].set_ylabel(u'Площадь общая, кв.м.')

axes[3,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' Выручка за оказание услуг, руб. ']],color='blue',label = u' Выручка за оказание услуг, руб. ')
axes[3,1].set_xlabel(u' Валовая прибыль, руб. ')

axes[3,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' Товарная выручка, руб. ']],color='red',\
                  label = u' Товарная выручка, руб. ')
axes[3,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[3,1].set_ylabel(u'')
axes[3,1].legend(numpoints=1, loc='upper left')

axes[0,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[u'Площадь общая, кв.м.']])
axes[0,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[0,2].set_ylabel(u'Площадь общая, кв.м.')

axes[1,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[1,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[1,2].set_ylabel( u' Стоимость аренды и эксплуатация, руб. ')

axes[2,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[  u' OPEX + S&M, руб. ']])
axes[2,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[2,2].set_ylabel(  u' OPEX + S&M, руб. ')

axes[3,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[u' Численность населения, тыс. чел. ']])
axes[3,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[3,2].set_ylabel(u' Численность населения, тыс. чел. ')

for i, txt in enumerate(df[u'Город']):
    axes[3,2].annotate(txt, (df[u' Выручка за оказание услуг, руб. '].values[i],df[u' Численность населения, тыс. чел. '].values[i]))
    axes[2,2].annotate(txt, (df[u' Выручка за оказание услуг, руб. '].values[i],df[u' OPEX + S&M, руб. '].values[i]))

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets, cluster
lst = [u' Численность населения, тыс. чел. ', u'Площадь общая, кв.м.', \
     u' Подключения, аб. ', u' Подключения B2C, аб. ', u' Опции, шт. ', u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ',\
     u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ',\
     u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ', u' Аксессуары, шт. ', \
     u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ',\
     u' Консультации по CRM, шт. ', u' Действия по CRM, шт. ', u' Сервисные операции, оплачиваемые оператором, шт. ',\
     u' Средний трафик в мес., чел. ', u' Среднее количество принятых платежей через кассу в мес., шт. ',\
     u' Среднее количество платежей через собственные терминалы в мес., шт. ', \
     u' Средний очищенный трафик  от платежей (кассы, терминалы) в мес., чел. ', u' Выручка за оказание услуг, руб. ', \
     u' Товарная выручка, руб. ', u' Валовая прибыль, руб. ', u' Общая себестоимость товара, руб. ', u' ФОТ салона, руб. ',\
     u' Стоимость аренды и эксплуатация, руб. ', u' OPEX + S&M, руб. ',  u'Коэф-т затрат к 1 руб. прибыли',\
     u'Средняя выручка на 1 кв.м. в мес., руб.', u'Средняя прибыль на 1 кв.м. в мес., руб.']

print 'feature nmb %d ' % len (lst)
X = df[lst]
X = X.fillna(value = 0)
agglo = cluster.FeatureAgglomeration(n_clusters=10)
agglo.fit(X)

X_reduced = agglo.transform(X)

X_restored = agglo.inverse_transform(X_reduced)
X_restored.shape

printByClusters(X.columns, agglo.labels_)
# Out:
# feature nmb 32
# ---------- 0----------
#  Все сервисные операции по CRM, шт.
#  Действия по CRM, шт.
#  Средний трафик в мес., чел.
#  Средний очищенный трафик  от платежей (кассы, терминалы) в мес., чел.
# Средняя выручка на 1 кв.м. в мес., руб.
# Средняя прибыль на 1 кв.м. в мес., руб.
# ---------- 1----------
# Площадь общая, кв.м.
#  Подключения, аб.
#  Подключения B2C, аб.
#  Опции, шт.
#  Опции оплачиваемые оператором, шт.
#  Смартфоны, шт.
#  Планшеты, шт.
#  Телефоны, шт.
#  Модемы/Роутеры, шт.
#  Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт.
#  Аксессуары, шт.
#  Средний чек (с учетом платежей), руб.
#  Средний чек платежный, руб.
#  Консультации по CRM, шт.
#  Сервисные операции, оплачиваемые оператором, шт.
#  Среднее количество принятых платежей через кассу в мес., шт.
#  Среднее количество платежей через собственные терминалы в мес., шт.
# Коэф-т затрат к 1 руб. прибыли
# ---------- 2----------
#  ФОТ салона, руб.
# ...

# %%
df[[u' Численность населения, тыс. чел. ']].hist(by=df[u'Расположение ССМ, ТЦ/Street'], bins = 40)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000005E3D39E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000589F9D68>], dtype=object)

# %%
df[u'Площадь общая, кв.м.'].hist(by=df[u'Расположение ССМ, ТЦ/Street'], bins = 10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000005F5C0E48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000005E975AC8>], dtype=object)

# %%
df[ u' Средний чек (с учетом платежей), руб. '].hist(by=df[u'Расположение ССМ, ТЦ/Street'], bins = 10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000056745390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000005E45DBA8>], dtype=object)

# %%
df[ u' Средний чек платежный, руб. '].hist(by=df[u'Расположение ССМ, ТЦ/Street'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000004E4D1518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000059292F28>], dtype=object)

# %% [markdown]
# ## Стандарт

# %%
df = data[data[ u'Тип салона']== u'Стандарт']
col = [u'Филиал', u'Область', u'Город', u'Магазин', u'Код 1С', u'Дата открытия салона', u'Дата закрытия салона',\
       u' Количество отработанных месяцев в 2014  ', u' Количество отработанных дней в 2014  ', u' Численность населения, тыс. чел. ',\
       u'Расположение ССМ, ТЦ/Street', u'Площадь общая, кв.м.', u'Среднее кол-во персонала в салоне, чел.',\
       u' Подключения, аб. ', u' Подключения B2C, аб. ', u' Опции, шт. ', u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ',\
       u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ', \
       u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ', u' Аксессуары, шт. ', \
       u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ', \
       u' Консультации по CRM, шт. ', u' Действия по CRM, шт. ', u' Сервисные операции, оплачиваемые оператором, шт. ', \
       u' Средний трафик в мес., чел. ', u' Среднее количество принятых платежей через кассу в мес., шт. ',\
       u' Среднее количество платежей через собственные терминалы в мес., шт. ',\
       u' Средний очищенный трафик  от платежей (кассы, терминалы) в мес., чел. ', \
       u' Выручка за оказание услуг, руб. ', u' Товарная выручка, руб. ', u' Валовая прибыль, руб. ', u' Общая себестоимость товара, руб. ',\
       u' ФОТ салона, руб. ', u' Стоимость аренды и эксплуатация, руб. ', u' OPEX + S&M, руб. ', u' Товарная выручка ССМ в мес, руб. ',\
       u' Общая выручка ССМ в мес, руб. ', u' Прибыль ССМ в мес., руб ', u' OPEX + S&M ССМ в мес., руб. ',\
       u'Коэф-т  затрат к 1 руб. выручки', u'Коэф-т затрат к 1 руб. прибыли', u'Средняя выручка на 1 кв.м. в мес., руб.', \
       u'Средняя прибыль на 1 кв.м. в мес., руб.']
df = df[col]

# %%
col = [u' Подключения, аб. ',u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ',\
       u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ',  u' Аксессуары, шт. ', \
       u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ', \
       u' Средний трафик в мес., чел. ', u' Среднее количество принятых платежей через кассу в мес., шт. ',\
       u' Выручка за оказание услуг, руб. ', u' Товарная выручка, руб. ', u' Валовая прибыль, руб. ', u' Общая себестоимость товара, руб. ',\
       u' ФОТ салона, руб. ', u' Стоимость аренды и эксплуатация, руб. ', u' OPEX + S&M, руб. ',\
       u'Коэф-т затрат к 1 руб. прибыли', u'Средняя прибыль на 1 кв.м. в мес., руб.']
df_sc = df[col]
#plt.xlabel(u' Численность населения, тыс. чел. ')
#plt.ylabel(u' Все мобильное оборудование ')
fig, axes = plt.subplots(nrows=4, ncols=3,figsize = (20,20))
axes[0,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ']])
axes[0,0].set_xlabel(u' Численность населения')
axes[0,0].set_ylabel(u' Все мобильное оборудование')

axes[1,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Товарная выручка, руб. ']])
axes[1,0].set_xlabel(u' Численность населения')
axes[1,0].set_ylabel(u' Товарная выручка, руб. ')

axes[2,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[2,0].set_xlabel(u' Численность населения')
axes[2,0].set_ylabel(u' Стоимость аренды и эксплуатация, руб. ')

axes[3,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[u' OPEX + S&M, руб. ']])
axes[3,0].set_xlabel(u' Численность населения')
axes[3,0].set_ylabel(u' OPEX + S&M, руб. ')


axes[0,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' OPEX + S&M, руб. ']])
axes[0,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[0,1].set_ylabel(u' OPEX + S&M, руб. ')

axes[1,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[1,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[1,1].set_ylabel( u' Стоимость аренды и эксплуатация, руб. ')

axes[2,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u'Площадь общая, кв.м.']])
axes[2,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[2,1].set_ylabel(u'Площадь общая, кв.м.')

axes[3,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' Выручка за оказание услуг, руб. ']],color='blue',label = u' Выручка за оказание услуг, руб. ')
axes[3,1].set_xlabel(u' Валовая прибыль, руб. ')

axes[3,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' Товарная выручка, руб. ']],color='red',\
                  label = u' Товарная выручка, руб. ')
axes[3,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[3,1].set_ylabel(u'')
axes[3,1].legend(numpoints=1, loc='upper left')

axes[0,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[u'Площадь общая, кв.м.']])
axes[0,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[0,2].set_ylabel(u'Площадь общая, кв.м.')

axes[1,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[1,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[1,2].set_ylabel( u' Стоимость аренды и эксплуатация, руб. ')

axes[2,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[  u' OPEX + S&M, руб. ']])
axes[2,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[2,2].set_ylabel(  u' OPEX + S&M, руб. ')

axes[3,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[u' Численность населения, тыс. чел. ']])
axes[3,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[3,2].set_ylabel(u' Численность населения, тыс. чел. ')

# %% [markdown]
# ## Остров

# %%
df = data[data[ u'Тип салона']== u'Остров']
col = [u'Филиал', u'Область', u'Город', u'Магазин', u'Код 1С', u'Дата открытия салона', u'Дата закрытия салона',\
       u' Количество отработанных месяцев в 2014  ', u' Количество отработанных дней в 2014  ', u' Численность населения, тыс. чел. ',\
       u'Расположение ССМ, ТЦ/Street', u'Площадь общая, кв.м.', u'Среднее кол-во персонала в салоне, чел.',\
       u' Подключения, аб. ', u' Подключения B2C, аб. ', u' Опции, шт. ', u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ',\
       u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ', \
       u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ', u' Аксессуары, шт. ', \
       u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ', \
       u' Консультации по CRM, шт. ', u' Действия по CRM, шт. ', u' Сервисные операции, оплачиваемые оператором, шт. ', \
       u' Среднее количество принятых платежей через кассу в мес., шт. ',\
       u' Выручка за оказание услуг, руб. ', u' Товарная выручка, руб. ', u' Валовая прибыль, руб. ', u' Общая себестоимость товара, руб. ',\
       u' ФОТ салона, руб. ', u' Стоимость аренды и эксплуатация, руб. ', u' OPEX + S&M, руб. ', u' Товарная выручка ССМ в мес, руб. ',\
       u' Общая выручка ССМ в мес, руб. ', u' Прибыль ССМ в мес., руб ', u' OPEX + S&M ССМ в мес., руб. ',\
       u'Коэф-т  затрат к 1 руб. выручки', u'Коэф-т затрат к 1 руб. прибыли', u'Средняя выручка на 1 кв.м. в мес., руб.', \
       u'Средняя прибыль на 1 кв.м. в мес., руб.']
df = df[col]

# %%
col = [u' Подключения, аб. ',u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ',\
       u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ',  u' Аксессуары, шт. ', \
       u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ', \
       u' Среднее количество принятых платежей через кассу в мес., шт. ',\
       u' Выручка за оказание услуг, руб. ', u' Товарная выручка, руб. ', u' Валовая прибыль, руб. ', u' Общая себестоимость товара, руб. ',\
       u' ФОТ салона, руб. ', u' Стоимость аренды и эксплуатация, руб. ', u' OPEX + S&M, руб. ',\
       u'Коэф-т затрат к 1 руб. прибыли', u'Средняя прибыль на 1 кв.м. в мес., руб.']
df_sc = df[col]
#plt.xlabel(u' Численность населения, тыс. чел. ')
#plt.ylabel(u' Все мобильное оборудование ')
fig, axes = plt.subplots(nrows=4, ncols=3,figsize = (20,20))
axes[0,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ']])
axes[0,0].set_xlabel(u' Численность населения')
axes[0,0].set_ylabel(u' Все мобильное оборудование')

axes[1,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Товарная выручка, руб. ']])
axes[1,0].set_xlabel(u' Численность населения')
axes[1,0].set_ylabel(u' Товарная выручка, руб. ')

axes[2,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[2,0].set_xlabel(u' Численность населения')
axes[2,0].set_ylabel(u' Стоимость аренды и эксплуатация, руб. ')

axes[3,0].scatter(df[[u' Численность населения, тыс. чел. ']],df[[u' OPEX + S&M, руб. ']])
axes[3,0].set_xlabel(u' Численность населения')
axes[3,0].set_ylabel(u' OPEX + S&M, руб. ')


axes[0,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' OPEX + S&M, руб. ']])
axes[0,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[0,1].set_ylabel(u' OPEX + S&M, руб. ')

axes[1,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[1,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[1,1].set_ylabel( u' Стоимость аренды и эксплуатация, руб. ')

axes[2,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u'Площадь общая, кв.м.']])
axes[2,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[2,1].set_ylabel(u'Площадь общая, кв.м.')

axes[3,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' Выручка за оказание услуг, руб. ']],color='blue',label = u' Выручка за оказание услуг, руб. ')
axes[3,1].set_xlabel(u' Валовая прибыль, руб. ')

axes[3,1].scatter(df[[u' Валовая прибыль, руб. ']],df[[u' Товарная выручка, руб. ']],color='red',\
                  label = u' Товарная выручка, руб. ')
axes[3,1].set_xlabel(u' Валовая прибыль, руб. ')
axes[3,1].set_ylabel(u'')
axes[3,1].legend(numpoints=1, loc='upper left')

axes[0,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[u'Площадь общая, кв.м.']])
axes[0,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[0,2].set_ylabel(u'Площадь общая, кв.м.')

axes[1,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[ u' Стоимость аренды и эксплуатация, руб. ']])
axes[1,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[1,2].set_ylabel( u' Стоимость аренды и эксплуатация, руб. ')

axes[2,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[  u' OPEX + S&M, руб. ']])
axes[2,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[2,2].set_ylabel(  u' OPEX + S&M, руб. ')

axes[3,2].scatter(df[[u' Выручка за оказание услуг, руб. ']],df[[u' Численность населения, тыс. чел. ']])
axes[3,2].set_xlabel(u' Выручка за оказание услуг, руб. ')
axes[3,2].set_ylabel(u' Численность населения, тыс. чел. ')

# %%
df[u' Численность населения, тыс. чел. '].hist(bins = 30)

# %%
df[u' Численность населения, тыс. чел. '].hist(by=df[u'Филиал'], figsize = (10,10))#, u'Область',
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000060B0FD68>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000620AB320>]], dtype=object)

# %%
from sklearn.decomposition import TruncatedSVD

# %%
col = [ u' Количество отработанных месяцев в 2014  ', u' Численность населения, тыс. чел. ',\
       u'Площадь общая, кв.м.', u'Среднее кол-во персонала в салоне, чел.',\
       u' Подключения, аб. ', u' Подключения B2C, аб. ', u' Опции, шт. ', u' Опции оплачиваемые оператором, шт. ', u' Смартфоны, шт. ',\
       u' Планшеты, шт.  ', u' Телефоны, шт. ', u' Модемы/Роутеры, шт. ', \
       u' Все мобильное оборудование (смартфоны, планшеты, телефоны, модемы и роутеры, с учетом кастомов), шт. ', u' Аксессуары, шт. ', \
       u' Средний чек (с учетом платежей), руб. ', u' Средний чек платежный, руб. ', u' Все сервисные операции по CRM, шт. ', \
       u' Консультации по CRM, шт. ', u' Действия по CRM, шт. ', u' Сервисные операции, оплачиваемые оператором, шт. ', \
       u' Среднее количество принятых платежей через кассу в мес., шт. ',\
       u' Выручка за оказание услуг, руб. ', u' Товарная выручка, руб. ', u' Валовая прибыль, руб. ', u' Общая себестоимость товара, руб. ',\
       u' ФОТ салона, руб. ', u' Стоимость аренды и эксплуатация, руб. ', u' OPEX + S&M, руб. ', u' Товарная выручка ССМ в мес, руб. ',\
       u' Общая выручка ССМ в мес, руб. ', u' Прибыль ССМ в мес., руб ', u' OPEX + S&M ССМ в мес., руб. ',\
       u'Коэф-т  затрат к 1 руб. выручки', u'Коэф-т затрат к 1 руб. прибыли', u'Средняя выручка на 1 кв.м. в мес., руб.', \
       u'Средняя прибыль на 1 кв.м. в мес., руб.']
print 'features = %d' %len(col)
# Out:
# features = 36

# %%
n_components = 4
matrix  = df[col]
matrix = matrix.dropna()
svd = TruncatedSVD(n_components)
svd.fit(matrix.as_matrix())

explained_variance = svd.explained_variance_ratio_.sum()
print("Explained variance of the SVD step: {}%".format(
    int(explained_variance * 100)))
# Out:
# Explained variance of the SVD step: 99%

# %%
columns = np.array(col)
print '-------1-------'
for i,txt in enumerate(col):
    if svd.components_[0][i]>0.01:
        print columns[i]
print '-------2-------'
for i,txt in enumerate(col):
    if svd.components_[1][i]>0.01:
        print columns[i]
print '-------3-------'
for i,txt in enumerate(col):
    if svd.components_[2][i]>0.01:
        print columns[i]
# Out:
# -------1-------
#  Численность населения, тыс. чел.
#  Выручка за оказание услуг, руб.
#  Товарная выручка, руб.
#  Валовая прибыль, руб.
#  Общая себестоимость товара, руб.
#  ФОТ салона, руб.
#  Стоимость аренды и эксплуатация, руб.
#  OPEX + S&M, руб.
#  Товарная выручка ССМ в мес, руб.
#  Общая выручка ССМ в мес, руб.
#  Прибыль ССМ в мес., руб
#  OPEX + S&M ССМ в мес., руб.
# -------2-------
#  Численность населения, тыс. чел.
#  Выручка за оказание услуг, руб.
#  Валовая прибыль, руб.
#  Стоимость аренды и эксплуатация, руб.
#  OPEX + S&M, руб.
# -------3-------
#  Выручка за оказание услуг, руб.
#  Валовая прибыль, руб.
#  ФОТ салона, руб.
#  Стоимость аренды и эксплуатация, руб.
#  OPEX + S&M, руб.
#  Прибыль ССМ в мес., руб
#  OPEX + S&M ССМ в мес., руб.

# %%
plt.plot(svd.components_.T,'.-')
